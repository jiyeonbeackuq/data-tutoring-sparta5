# %% [markdown]
# <a href="https://colab.research.google.com/github/jiyeonbeackuq/data-tutoring-sparta5/blob/main/%5BFull%5D_Pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📌 Pandas
# **┗ customers/orders/payments 데이터 실습**
# ---
# > **목차(Context)**
#
# * 🔈Day01 - 데이터 로딩, 확인, 병합, 칼럼명 변경, 저장
# * 🔉Day02 - 데이터 선택, 변형, 결측값처리 - 삭제/삽입
# * 🔊Day03 - 중복값 처리, 시계열처리, 그룹화, 피봇팅

# %%
# 주피터 노트북으로 실행 시/ 코랩에서 데이터 마운트해서 사용할 해당 코드 삭제

# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

# ▶ 경로 설정 (※강의자료가 위치에 있는 경로 확인)
import os
os.chdir('/content/drive/MyDrive/data/')
os.getcwd()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/data'

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# # Day01 - 데이터 로딩, 확인, 병합, 칼럼명 변경, 저장
# * total.xlsx 이용

# %% [markdown]
# # 1-1) 데이터 로딩

# %% [markdown]
# > **pd.read_excel("filename", sheet_name = 0, header = 0)**
#
# > sheet_name 파라미터 설명
# * 0: 1번째 시트만 읽어옴 (기본값)
# * 1: 2번째 시트만 읽어옴
# * "Sheet1": 시트 이름을 기준으로 읽어옴
# * [0, 1, "Sheet5"]: 1, 2번째 시트와 "Sheet5" 라는 이름의 시트를 읽어옴
# * None: 모든 시트를 읽어옴 (dictionary 형태로 읽어옴)

# %% [markdown]
# **▶ total.xlsx 읽어서 df에 할당**

# %%
# orders = pd.read_csv('orders.csv')
# customers = pd.read_csv('customers.csv')
# payments = pd.read_csv('payments.csv')

# ▶ Data read

# %%
df.keys()
# Out:
# dict_keys(['orders_2016', 'orders_2017', 'orders_2018', 'customers', 'payments'])

# %% [markdown]
# # 1-2) 데이터 확인

# %% [markdown]
# * 데이터의 기본 정보들을 확인
#
#   (1) Data shape(형태) 확인: shape
#
#   (2) Data type 확인: dtypes
#
#   (+) columns 확인: columns
#       Null값 확인 (※ 빈 값의 Data): isnull/isna

# %% [markdown]
# **▶ orders_2016 ~ 2018, cusotmers, payments의 shape 확인**

# %%
# Out:
# (3, 8)
# (464, 8)
# (533, 8)
# (1000, 5)
# (1000, 5)

# %%
# for문으로 코드 간소화 해보기
# Out:
# orders_2016 : (3, 8)
# orders_2017 : (464, 8)
# orders_2018 : (533, 8)
# customers : (1000, 5)
# payments : (1000, 5)

# %% [markdown]
# **▶ orders_2016 ~ 2018, cusotmers, payments의 type 확인**

# %%
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object
# order_id                                 object
# customer_id                              object
# order_status                             object
# ...

# %%
# for문으로 코드 간소화 해보기
# Out:
# orders_2016
#  order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object
# ...
# orders_2017
#  order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object
# ...
# orders_2018
#  order_id                                 object
# customer_id                              object
# ...

# %% [markdown]
# # 1-3) 데이터 연결
# * orders 2016 ~ 2018을 orders 로 합치기
# * pd.concat([], axis = 0, ignore_index = False)

# %% [markdown]
# **▶ orders_2016 ~ 2018 columns 확인**

# %%
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %% [markdown]
# **▶ orders_2016 ~ 2018 concat하여, orders 생성**

# %%
# ▶ Data concat
# Out:
# (1000, 8)
#                              order_id                       customer_id  \
# 0    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 1    cbbb524a0e1646aa6cf7a3c0bbe517ad  dacb079d55ffb1d3955c5d923df3ebb7
# 2    ac2b7c522d811acba0aa270ed3e112e4  ef21aebbb093a6db29ccc6aa0b89c347
# 3    e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4    949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# ..                                ...                               ...
# 995  38097aba0f729783af8bf48eabf5e496  5a07aa8c5c8860866b5557e83d75a4e2
# 996  b436fd24a04e7267307e1d900faa8eb1  20217ca968adf8f08c5916bf09c33d7f
# 997  ef5b03340b5839974405018a62e03f29  7c1e106bfe425aafa689ac08293ee6b8
# 998  f056d4857c146c38ff02566b3e152bca  fc6408fa8083f3c01b1f287709714321
# 999  8e3f8be6e1ce8ec5b39dae59e0aabcff  6520161e793f944073a132d97e9af083
#
#     order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# # 1-4) column 이름 변경
# * df.rename(columns = {}, inplace = False)

# %% [markdown]
# **▶ orders 테이블 칼럼을 다음과 같이 바꿔보자.**
# >>
# 'order_id': '주문ID',
# 'customer_id': '고객ID',
# 'order_status': '주문상태',
# 'order_purchase_timestamp': '주문시간',
# 'order_approved_at': '승인시간', 'order_delivered_carrier_date':'배송출발시간',
# 'order_delivered_customer_date':'배송시간', 'order_estimated_delivery_date':'배송예상시간'

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 1  cbbb524a0e1646aa6cf7a3c0bbe517ad  dacb079d55ffb1d3955c5d923df3ebb7
# 2  ac2b7c522d811acba0aa270ed3e112e4  ef21aebbb093a6db29ccc6aa0b89c347
#
#          주문상태                주문시간                승인시간              배송출발시간  \
# 0  processing 2016-10-05 22:44:13 2016-10-06 15:51:05                 NaT
# 1   delivered 2016-10-05 07:31:49 2016-10-06 02:46:24 2016-10-10 02:46:24
# 2   delivered 2016-10-05 15:08:00 2016-10-06 15:44:26 2016-10-10 15:44:27
#
#                  배송시간     배송예상시간
# 0                 NaT 2016-12-09
# 1 2016-10-16 14:36:00 2016-12-07
# 2 2016-10-13 15:44:27 2016-11-29

# %% [markdown]
# **▶ payments 테이블 칼럼을 다음과 같이 바꿔보자.**
# >>
# 'order_id':'주문ID',
# 'payment_sequential':'결제횟수',
# 'payment_type':'결제방식',
# 'payment_installments':'할부수', 'payment_value':'결제금액'

# %%
# Out:
#                                주문ID  결제횟수         결제방식  할부수   결제금액
# 0  b81ef226f3fe1789b1e8b2acac839d17     1  credit_card    8  99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0     1  credit_card    1  24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd     1  credit_card    1  65.71

# %% [markdown]
# **▶ customers 테이블 칼럼을 다음과 같이 바꿔보자.**
# >>
# 'customer_id':'고객ID', 'customer_unique_id':'고객고유ID', 'customer_zip_code_prefix':'우편번호',
# 'customer_city':'도시', 'customer_state':'주'

# %%
# Out:
#                                고객ID                            고객고유ID   우편번호  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0  14409
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3   9790
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e   1151
#
#                       도시   주
# 0                 franca  SP
# 1  sao bernardo do campo  SP
# 2              sao paulo  SP

# %% [markdown]
# # 1-5) 데이터 병합
# * 두개의 데이터프레임을 합쳐보자
# * pd.merge(df1, df2, how = "inner", on = "column_name")

# %% [markdown]
# **▶ customers에 orders를 merge해보자 (customers2 생성)**

# %%
# Out:
# Index(['주문ID', '고객ID', '주문상태', '주문시간', '승인시간', '배송출발시간', '배송시간', '배송예상시간'], dtype='object')

# %%
# Out:
# Index(['고객ID', '고객고유ID', '우편번호', '도시', '주'], dtype='object')

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  22ff7c206b68858435452298296c2fcb  5ad934ace4646e3dad70148a823eb138
# 1  5f69f6bf68dce110479aa0bb515b47c8  4cd274ce8ba240b1cff6480fa9911df1
# 2  4a5cc9b4e332e03d76bf553a7f2fa5d3  a4a00c41b5e3ed88bf0e0bb96576c2b2
# 3  0daf1f0e67b534ad873ba61c5d6ad7d3  1681471e9172d7e12ba08e9ac9e8628b
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 5  f11b36b3bc7bacf06deef862ed611f02  ae8db0691449a44352e7d535ddf78c5e
# 6  cd0019d8419b82109ff269d8b4e18791  17ebae22126d3df35f5e1fa1efedab94
# 7  e311f8fc30348d6213964a43f70f87fb  6ca7c0e971c24ce0931f148588ef23ce
# 8  760312f5735ee281f01e56d5ddee05e3  4b003ee1eabaffe8ff8e6d75394a9b42
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-04-27 10:24:22 2017-04-27 10:35:12 2017-04-28 14:07:00
# 1  delivered 2017-11-26 11:20:27 2017-11-26 11:31:40 2017-11-27 16:36:45
# ...

# %% [markdown]
# **▶ payments에 orders를 merge해보자 (payments2 생성)**

# %%
# Out:
# Index(['주문ID', '결제횟수', '결제방식', '할부수', '결제금액'], dtype='object')

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수         결제방식  할부수    결제금액
# ...

# %% [markdown]
# # 1-6) 데이터 저장
# * df.to_csv("filename", index = True)
# ** 한글깨짐 현상 방지: encoding = "UTF-8-SIG"
# * df.to_excel("filename", index = True)

# %% [markdown]
# **▶ customers2를 xlsx파일로 저장해보자 (customers2.xlsx)**

# %% [markdown]
# **▶ payments2를 csv파일로 저장해보자 (payments2.csv)**

# %% [markdown]
# # Day02 - 데이터 선택, 변형, 컬럼 추가,결측값 - 삭제/삽입

# %% [markdown]
# **▶ orders, payments2 확인**

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 1  cbbb524a0e1646aa6cf7a3c0bbe517ad  dacb079d55ffb1d3955c5d923df3ebb7
# 2  ac2b7c522d811acba0aa270ed3e112e4  ef21aebbb093a6db29ccc6aa0b89c347
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
#
#          주문상태                주문시간                승인시간              배송출발시간  \
# 0  processing 2016-10-05 22:44:13 2016-10-06 15:51:05                 NaT
# 1   delivered 2016-10-05 07:31:49 2016-10-06 02:46:24 2016-10-10 02:46:24
# 2   delivered 2016-10-05 15:08:00 2016-10-06 15:44:26 2016-10-10 15:44:27
# 3   delivered 2017-10-02 10:56:33 2017-10-02 11:07:15 2017-10-04 19:55:00
# 4   delivered 2017-11-18 19:28:06 2017-11-18 19:45:59 2017-11-22 13:39:59
#
#                  배송시간     배송예상시간
# 0                 NaT 2016-12-09
# ...

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수         결제방식  할부수    결제금액
# ...

# %% [markdown]
# # 2-1) 데이터 선택

# %% [markdown]
# * 고유값확인: df["col"].unique()
# * 고유값 count 확인: df["col"].values_counts()
# * df.loc[행조건, 열조건]
# * df.iloc[행index, 열index]

# %% [markdown]
# **▶orders - "주문상태" 고유값 확인**

# %%
# Out:
# array(['processing', 'delivered', 'invoiced', 'shipped', 'unavailable',
#        'canceled'], dtype=object)

# %% [markdown]
# **▶orders - "주문상태" 고유값 count 확인**

# %%
# Out:
# 주문상태
# delivered      975
# shipped         13
# unavailable      4
# processing       3
# invoiced         3
# canceled         2
# Name: count, dtype: int64

# %% [markdown]
# **▶ orders - 주문이 취소된 주문ID를 찾아보자**

# %%
# Out:
# 696    1b9ecfe83cdc259250e1a8aca174f0ad
# 801    714fb133a6730ab81fa1d3c1b2007291
# Name: 주문ID, dtype: object

# %% [markdown]
# **▶ orders - 주문이 취소된 행 찾아보자**

# %%
# Out:
#                                  주문ID                              고객ID  \
# 696  1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 801  714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
#
#          주문상태                주문시간                승인시간              배송출발시간  \
# 696  canceled 2018-08-04 14:29:27 2018-08-07 04:10:26                 NaT
# 801  canceled 2018-01-26 21:34:08 2018-01-26 21:58:39 2018-01-29 22:33:25
#
#     배송시간     배송예상시간
# 696  NaT 2018-08-14
# 801  NaT 2018-02-22

# %% [markdown]
# **▶ orders - 주문이 취소되고 배송출발 시간이 결측치인 행을 찾아보자**

# %%
# Out:
#                                  주문ID                              고객ID  \
# 696  1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
#
#          주문상태                주문시간                승인시간 배송출발시간 배송시간     배송예상시간
# 696  canceled 2018-08-04 14:29:27 2018-08-07 04:10:26    NaT  NaT 2018-08-14

# %% [markdown]
# **▶ orders - 주문이 취소된 행 찾아서, 첫번째 행만 선택 (loc생략)**

# %%
# Out:
#                                  주문ID                              고객ID  \
# 696  1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
#
#          주문상태                주문시간                승인시간 배송출발시간 배송시간     배송예상시간
# 696  canceled 2018-08-04 14:29:27 2018-08-07 04:10:26    NaT  NaT 2018-08-14

# %% [markdown]
# **▶ orders - 마지막 행 선택 (iloc이용)**

# %%
# Out:
# 주문ID      8e3f8be6e1ce8ec5b39dae59e0aabcff
# 고객ID      6520161e793f944073a132d97e9af083
# 주문상태                             delivered
# 주문시간                   2018-03-23 11:07:13
# 승인시간                   2018-03-27 03:56:17
# 배송출발시간                 2018-03-29 21:33:24
# 배송시간                   2018-04-11 23:41:16
# 배송예상시간                 2018-04-16 00:00:00
# Name: 999, dtype: object

# %% [markdown]
# **▶ payments2 결제금액 순으로 내림차순 정렬**

# %%
# Out:
#                                주문ID                              고객ID  \
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
#
#                  배송시간     배송예상시간  결제횟수         결제방식  할부수    결제금액
# ...

# %% [markdown]
# # 2-2) 데이터 변형

# %% [markdown]
# * **새로운 칼럼 생성**
# * **▶ payments2 - "결제금액(원)" 칼럼 생성**

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수         결제방식  할부수    결제금액   결제금액(원)
# ...

# %% [markdown]
# * **데이터 타입 변형**
# * **▶ payments2["결제금액(원)"] 타입을 int64로 변경**

# %%
# Out:
# 주문ID               object
# 고객ID               object
# 주문상태               object
# 주문시간       datetime64[ns]
# 승인시간       datetime64[ns]
# 배송출발시간     datetime64[ns]
# 배송시간       datetime64[ns]
# 배송예상시간     datetime64[ns]
# 결제횟수                int64
# 결제방식               object
# 할부수                 int64
# 결제금액              float64
# 결제금액(원)             int64
# dtype: object

# %% [markdown]
# * **컬럼 삭제**
# * **▶ payments2["결제금액"] 컬럼삭제 (inplace = True)로 놔두기**

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수         결제방식  할부수  결제금액(원)
# ...

# %% [markdown]
# * **데이터 변경**
# * **▶ payments2["결제방식"] - credit_card: "카드", boleto:"기타", voucher:"바우처"로 변경**

# %% [markdown]
# * **▶ payments2["고객구분"] 컬럼 생성 - 결제횟수1회: "첫구매", 결제횟수2회이상: "재구매"**

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수 결제방식  할부수    결제금액  결제금액(원) 고객구분
# ...

# %%
# payments2["고객구분"] = np.where(payments2["결제횟수"] > 1, "재구매", "첫구매")

# %% [markdown]
# # 2-3) 결측값 처리 (삭제)

# %% [markdown]
# * **▶ orders - 결측값 확인**

# %%
# Out:
# 주문ID       0
# 고객ID       0
# 주문상태       0
# 주문시간       0
# 승인시간       0
# 배송출발시간    11
# 배송시간      25
# 배송예상시간     0
# dtype: int64

# %%
orders.shape
# Out:
# (1000, 8)

# %% [markdown]
# * **▶ orders - "배송출발시간" 결측값 삭제**

# %%
orders.shape
# Out:
# (989, 8)

# %% [markdown]
# # 2-4) 결측값 처리 (삽입)

# %% [markdown]
# * **▶ orders - "배송시간" 결측값 처리를 다음과 같이 해보자**
# * 1) 배송출발시간 ~ 배송시간의 평균 구하기 (mean_delivery)
# * 2) 배송추정시간 = 배송출발시간 + mean_delivery
# * 3) 배송시간 결측값을 배송추정시간으로 대체

# %% [markdown]
# * **▶ 1) 배송출발시간 ~ 배송시간의 평균 구하기 (mean_delivery)**
# * **▶ orders - "배송출발시간", "배송시간"을 datetime으로 바꿔줘야함: pd.to_datetime**

# %%
# Out:
# Timedelta('9 days 02:56:35.751794871')

# %% [markdown]
# * **▶ 2) 배송추정시간 = 배송출발시간 + mean_delivery**

# %%
# Out:
#                                  주문ID                              고객ID  \
# 76   36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# 105  4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 188  6147a4d49752afd35a119d794e481588  938698ae953596e231326da5ff220f68
# 195  95e42e6aaf6264cd3e77c06b32dc3003  29ef1f160ce630146dafa02052e2c5bf
# 246  10918fe4d665fda80034712895c2b92f  e05a24d2c1d2cd3ae0482ecc1b4d069f
# 492  ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 553  6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# 641  3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
# 645  b68d69564a79dea4776afa33d1d2fcab  de1e5517fb50896bbdcff5814fb31802
# 660  f373335aac9a659de916f7170b8bc07a  f06a94a401e52fb019c72f2e8bbf6a2f
# 684  5869074071e0f56e9085dc3742c97b2a  7203eb38fea2b4a15dd6c39575314aa4
# 785  f633c884a99eb63866600655356d973e  b6e18008af6aeb4a5ce5574c15ca2b48
# ...

# %% [markdown]
# * **▶ orders copy해두기 (orders2 생성)**

# %% [markdown]
# * **▶ 3) 배송시간 결측값을 배송추정시간으로 대체**

# %%
# Out:
# 주문ID      d3d6788577c9592da441752e8a1dd5e3
# 고객ID      8628fac2267e8c8804525da99c10ed0e
# 주문상태                             delivered
# 주문시간                   2017-09-19 22:17:15
# 승인시간                   2017-09-20 07:55:14
# 배송출발시간                 2017-09-22 17:23:09
# 배송시간                   2017-10-10 18:43:53
# 배송예상시간                 2017-10-13 00:00:00
# 배송추정시간       2017-10-01 20:19:44.751794871
# Name: 44, dtype: object

# %%
# Out:
# 주문ID      0
# 고객ID      0
# 주문상태      0
# 주문시간      0
# 승인시간      0
# 배송출발시간    0
# 배송시간      0
# 배송예상시간    0
# 배송추정시간    0
# dtype: int64

# %% [markdown]
# * **▶ 3+) 배송추정시간 = 배송시간이 있으면 배송 시간으로 대체**

# %%
# Out:
# 주문ID         0
# 고객ID         0
# 주문상태         0
# 주문시간         0
# 승인시간         0
# 배송출발시간       0
# 배송시간        14
# 배송예상시간       0
# 배송(추정)시간     0
# dtype: int64

# %% [markdown]
# # Day03 - 중복값처리, 그룹화, 시계열처리, 피봇팅

# %% [markdown]
# # 3-1) 중복값 처리

# %% [markdown]
# **▶ orders - "주문ID"에서 앞 5글자만 추출해서 "ID" 만들기 - apply(lambda)**

# %%
orders['주문ID']
# Out:
# 1      cbbb524a0e1646aa6cf7a3c0bbe517ad
# 2      ac2b7c522d811acba0aa270ed3e112e4
# 3      e481f51cbdc54678b7cc49136f2d6af7
# 4      949d5b44dbf5de918fe9c16f97b45f8a
# 5      a4591c265e18cb1dcee52889e2d8acc3
#                      ...
# 995    38097aba0f729783af8bf48eabf5e496
# 996    b436fd24a04e7267307e1d900faa8eb1
# 997    ef5b03340b5839974405018a62e03f29
# 998    f056d4857c146c38ff02566b3e152bca
# 999    8e3f8be6e1ce8ec5b39dae59e0aabcff
# Name: 주문ID, Length: 989, dtype: object

# %%
# Out:
#                                주문ID                              고객ID  \
# 1  cbbb524a0e1646aa6cf7a3c0bbe517ad  dacb079d55ffb1d3955c5d923df3ebb7
# 2  ac2b7c522d811acba0aa270ed3e112e4  ef21aebbb093a6db29ccc6aa0b89c347
# 3  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 4  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 1  delivered 2016-10-05 07:31:49 2016-10-06 02:46:24 2016-10-10 02:46:24
# 2  delivered 2016-10-05 15:08:00 2016-10-06 15:44:26 2016-10-10 15:44:27
# 3  delivered 2017-10-02 10:56:33 2017-10-02 11:07:15 2017-10-04 19:55:00
# 4  delivered 2017-11-18 19:28:06 2017-11-18 19:45:59 2017-11-22 13:39:59
# 5  delivered 2017-07-09 21:57:05 2017-07-09 22:10:13 2017-07-11 14:58:04
#
#                  배송시간     배송예상시간                        배송추정시간     ID
# ...

# %% [markdown]
# **▶ orders["ID"] 중복된 것 확인 (keep = False)**

# %%
# Out:
#                                  주문ID                              고객ID  \
# 510  6abaad69b8b349c3a529b4b91ce18e46  f5618502bee8eafdee72fb6955e2ebdf
# 951  6abaa1126b7b6ae01eb168ec3da96dac  6c2a5ea4fbd1854c3827a5e3b8eaf8cd
#
#           주문상태                주문시간                승인시간              배송출발시간  \
# 510  delivered 2018-02-15 10:33:30 2018-02-15 10:47:59 2018-02-20 14:15:09
# 951  delivered 2018-06-16 19:42:55 2018-06-16 19:58:28 2018-06-18 10:05:00
#
#                    배송시간     배송예상시간                        배송추정시간     ID
# 510 2018-02-24 19:15:56 2018-03-07 2018-03-01 17:11:44.751794871  6abaa
# 951 2018-06-25 20:21:34 2018-07-16 2018-06-27 13:01:35.751794871  6abaa

# %%
orders.shape
# Out:
# (989, 10)

# %% [markdown]
# **▶ orders["ID"] 중복값 지우기 (마지막 행 남기기)**

# %%
orders[orders['ID'].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [주문ID, 고객ID, 주문상태, 주문시간, 승인시간, 배송출발시간, 배송시간, 배송예상시간, 배송추정시간, ID]
# Index: []

# %% [markdown]
# **▶ orders - "고객ID"에서 앞 5글자만 추출해서 "CID" 만들기 - apply(lambda)**

# %%
orders['고객ID']
# Out:
# 1      dacb079d55ffb1d3955c5d923df3ebb7
# 2      ef21aebbb093a6db29ccc6aa0b89c347
# 3      9ef432eb6251297304e76186b10a928d
# 4      f88197465ea7920adcdbec7375364d82
# 5      503740e9ca751ccdda7ba28e9ab8f608
#                      ...
# 995    5a07aa8c5c8860866b5557e83d75a4e2
# 996    20217ca968adf8f08c5916bf09c33d7f
# 997    7c1e106bfe425aafa689ac08293ee6b8
# 998    fc6408fa8083f3c01b1f287709714321
# 999    6520161e793f944073a132d97e9af083
# Name: 고객ID, Length: 988, dtype: object

# %%
orders[orders['CID'].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [주문ID, 고객ID, 주문상태, 주문시간, 승인시간, 배송출발시간, 배송시간, 배송예상시간, 배송추정시간, ID, CID]
# Index: []

# %% [markdown]
# # 3-2) 시계열 처리

# %% [markdown]
# **▶ payments2 - "주문시간" datetime형태로 type 변환**

# %%
payments2['주문시간']
# Out:
# 0   2017-10-04 11:31:15
# 1   2017-08-31 11:38:18
# 2   2018-05-23 16:37:35
# 3   2018-01-14 18:49:14
# 4   2018-02-21 13:48:55
# Name: 주문시간, dtype: datetime64[ns]

# %% [markdown]
# **▶payments2에서 '주문시간' 칼럼을 이용해 연도만 추출하기 ("주문년도" 생성)**

# %% [markdown]
# **▶payments2에서 '주문시간' 칼럼을 이용해 월만 추출하기 ("주문월" 생성)**

# %% [markdown]
# **▶payments2에서 '주문시간' 칼럼을 이용해 일만 추출하기 ("주문일" 생성)**

# %%
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수 결제방식  할부수    결제금액  결제금액(원) 고객구분  주문년도  \
# ...

# %% [markdown]
# **▶payments2에서 "주문연월" 컬럼을 생성해보자**

# %%
# Out:
# 0    2017-10
# 1     2017-8
# 2     2018-5
# 3     2018-1
# 4     2018-2
# dtype: object

# %% [markdown]
# # 3-3) 그룹화

# %% [markdown]
# **▶payments2에서 "결제방식"별 "결제금액" 평균을 구해보자 (pay_mean) 생성**

# %% [markdown]
# **▶payments2에서 "결제방식"별 "결제금액" 평균, 합계 구해보자 (pay_groupby) 생성**

# %% [markdown]
# **▶인덱스를 컬럼으로 바꾸기**

# %%
# Out:
#   결제방식    결제금액
# 0   기타  250.86
# 1  바우처   48.91
# 2   카드   48.46

# %%
# Out:
#   결제방식    mean     sum
# 0   기타  250.86  501.72
# 1  바우처   48.91   48.91
# 2   카드   48.46   96.92

# %% [markdown]
# # 3-4) 피봇팅

# %% [markdown]
# **▶payments2에서 주문연월별 주문상태 및 결제방식에 따른 평균 결제 금액, 고유 count을 알아보자. 총합계 출력 (result)**

# %%
payments2
# Out:
#                                주문ID                              고객ID  \
# 0  407408433ee2a9ed77984aa5a06e2b2e  9f4c898706bf2b467ace0539e0319fcc
# 1  d0e9849de800fdb4cb3b5e6d42c6b367  b634dded0d0e31b899f16cb02e0ed1d0
# 2  b616f638cd86d92c7cbd06cf7484ee34  8458f7ae02bda5950ce48c01a720559a
# 3  dc400373e624e9b0435847a79813c658  4a00f00d951c167739888a1f16c56e8e
# 4  16e62e9da7d33d61b6f26ccf68bc962c  becd44b937217776c659d9465b22808d
#
#         주문상태                주문시간                승인시간              배송출발시간  \
# 0  delivered 2017-10-04 11:31:15 2017-10-04 11:49:17 2017-10-04 17:48:24
# 1  delivered 2017-08-31 11:38:18 2017-09-01 02:30:13 2017-09-01 21:22:28
# 2  delivered 2018-05-23 16:37:35 2018-05-23 16:56:50 2018-05-24 16:13:00
# 3  delivered 2018-01-14 18:49:14 2018-01-14 18:59:30 2018-01-16 20:15:54
# 4  delivered 2018-02-21 13:48:55 2018-02-23 02:08:59 2018-02-23 22:22:02
#
#                  배송시간     배송예상시간  결제횟수 결제방식  할부수    결제금액  결제금액(원) 고객구분  주문년도  \
# ...

# %%
# Out:
#            주문상태 결제방식    mean                                           count  \
# 주문연월                 2017-08 2017-10 2018-01 2018-02 2018-05     All 2017-08
# 0     delivered   기타   85.79    0.00    0.00  415.93    0.00  250.86       1
# 1     delivered  바우처    0.00    0.00   48.91    0.00    0.00   48.91       0
# 2     delivered   카드    0.00   76.17    0.00    0.00   20.75   48.46       0
# 3           All        85.79   76.17   48.91  415.93   20.75  129.51       1
#
#
# 주문연월 2017-10 2018-01 2018-02 2018-05 All
# 0          0       0       1       0   2
# 1          0       1       0       0   1
# 2          1       0       0       1   2
# 3          1       1       1       1   5

# %% [markdown]
# **▶result를 csv로 저장(result.csv)**
